# %%
from ase.io.trajectory import TrajectoryReader as tr

import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from publish_format import useLargeSize

import re

# %%
color = {"DFT": "k",
         "AMPtorch DFT\n(with force)": "tab:orange",
         "AMPtorch DFT\n(without force)": "tab:blue",
         "AMPtorch DMC": "tab:red"}

# %%
def extract_forces(filename):
    forces = []
    trajs = tr(filename)
    for traj in trajs:
        forces.append(np.linalg.norm(np.array(traj.get_forces())))
    return np.array(forces)


def extract_geom(filename):
    '''
    "C C"
    '''
    d_c_c = []
    
    trajs = tr(filename)
    for traj in trajs:
        d_c_c.append(traj.get_distances(0, 1)[0])
        
    data = pd.DataFrame(
        {r"$d_{C-C}$": d_c_c, 
         }
    )
    return data

# %% [markdown]
# ## NVE results analysis

# %% [markdown]
# Define the corresponding NVE trajectories

# %%
file = {}

file["DFT"] = "./nvt_data/dft/md_nvt_dft.traj"
file["AMPtorch DFT\n(with force)"] = "./nvt_data/amptorch_dft_force/md_nvt_amptorch.traj"
file["AMPtorch DFT\n(without force)"] = "./nvt_data/amptorch_dft_noforce/md_nvt_amptorch.traj"
file["AMPtorch DMC"] = "./nvt_data/amptorch_dmc/md_nvt_amptorch.traj"

# %%
# show the running time for each trajectories
for item in file:
    print(item, " has length ", len(tr(file[item])))
# Out:
# DFT  has length  120
# AMPtorch DFT
# (with force)  has length  201
# AMPtorch DFT
# (without force)  has length  201
# AMPtorch DMC  has length  201

# %% [markdown]
# Check starting structures

# %%
for item in file:
    print(item)
    print(tr(file[item])[0].get_positions())
# Out:
# DFT
# [[6.87899729 7.49999705 7.49999705]
#  [8.1209968  7.49999705 7.49999705]]
# AMPtorch DFT
# (with force)
# [[6.87899729 7.49999705 7.49999705]
#  [8.1209968  7.49999705 7.49999705]]
# AMPtorch DFT
# (without force)
# [[6.87899729 7.49999705 7.49999705]
#  [8.1209968  7.49999705 7.49999705]]
# AMPtorch DMC
# [[6.87899729 7.49999705 7.49999705]
#  [8.1209968  7.49999705 7.49999705]]

# %% [markdown]
# ### Extract mean values for the observables

# %%
for item in file:
    geom = extract_geom(file[item])
    print(item)
    print(geom.mean())
# Out:
# DFT
# $d_{C-C}$    1.25893
# dtype: float64
# AMPtorch DFT
# (with force)
# $d_{C-C}$    1.250811
# dtype: float64
# AMPtorch DFT
# (without force)
# $d_{C-C}$    1.248146
# dtype: float64
# AMPtorch DMC
# $d_{C-C}$    1.23344
# dtype: float64

# %% [markdown]
# ### Plot the Energy trajectory

# %%
def extract_total_energy(filename):
    energy = []
    trajs = tr(filename)
    for traj in trajs:
        energy.append(traj.get_total_energy())
    return np.array(energy)

tot_e = {}
for item in file:
    tot_e[item] = extract_total_energy(file[item])
    tot_e[item] -= np.min(tot_e[item])
    # tot_e[item] /= 5

# %%
def extract_potential_energy(filename):
    energy = []
    trajs = tr(filename)
    for traj in trajs:
        energy.append(traj.get_potential_energy())
    return np.array(energy)

pot_e = {}
for item in file:
    pot_e[item] = extract_potential_energy(file[item])
    pot_e[item] -= min(pot_e[item])

# %%
def extract_kinetic_energy(filename):
    energy = []
    trajs = tr(filename)
    for traj in trajs:
        energy.append(traj.get_kinetic_energy())
    return np.array(energy)

kin_e = {}
for item in file:
    kin_e[item] = extract_kinetic_energy(file[item])

# %% [markdown]
# Plot the $E_{tot}$ v.s. Time

# %%
plot_data = tot_e

start, end = 0, min(1000, len(plot_data["DFT"]))
start, end = 0, 120
time = np.arange(end)
figname = "c2_nvt_etot_{}.png".format(end)
xlabel = r"$T\,(fs)$"
ylabel = r"$E_{tot}$ (eV)"
# ylabel = r"Relative Energy (eV/atom)"

plt.style.use('default')
fig, ax = plt.subplots(figsize=(16,6))

for item in plot_data:
    if item == "AMPtorch DFT\n(with force)":
        ax.plot(time, 
                plot_data[item][start:end],
                c=color[item],
                # linestyle="dashed",
                label=item)
    else:
        ax.plot(time, 
                plot_data[item][start:end],
                c=color[item],
                label=item)

ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.tick_params(axis="y")
ax.yaxis.set_ticks_position("both")
ax.xaxis.set_ticks_position("both")
ax.legend(loc='center left', bbox_to_anchor=(0.1, 0.9), frameon=False, fontsize=18, ncol=4)
ax.set_xlim(start, end)
# ax.set_ylim(-0.005, 0.04)
useLargeSize(plt, ax)
plt.savefig("./nvt_data/{}".format(figname), dpi=300)

# %% [markdown]
# plot $E_{tot}$ distribution

# %%
plot_data = tot_e
figname = "c2_nvt_etot_distribution.png"
ylabel = r"Density"
xlabel = r"$E_{tot}$ (eV)"

plt.style.use('default')
fig, ax = plt.subplots(figsize=(8,6))

for item in plot_data:
    sns.kdeplot(plot_data[item][:120], 
                shade = True, 
                linewidth = 3, 
                bw_adjust = 1, 
                label = item, 
                color = color[item],
            )

ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.tick_params(axis="y")
ax.yaxis.set_ticks_position("both")
ax.xaxis.set_ticks_position("both")
ax.legend(frameon=False, fontsize=18)
# ax.set_ylim(0, 70)
useLargeSize(plt, ax)
plt.savefig("./nvt_data/{}".format(figname), dpi=300)

# %% [markdown]
# plot $E_{pot}$ v.s. time

# %%
plot_data = pot_e

# start, end = 0, min(1000, len(plot_data["DFT"]))
start, end = 0, 120
time = np.arange(end)
figname = "c2_nvt_epot_{}.png".format(end)
xlabel = r"$T\,(fs)$"
ylabel = r"$E_{pot}\,(eV$)"

plt.style.use('default')
fig, ax = plt.subplots(figsize=(16,6))

for item in plot_data:
    if item == "AMPtorch DFT\n(with force)":
        ax.plot(time, 
                plot_data[item][start:end],
                c=color[item],
                # linestyle="dashed",
                label=item)
    else:
        ax.plot(time, 
                plot_data[item][start:end],
                c=color[item],
                label=item)

ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.tick_params(axis="y")
ax.yaxis.set_ticks_position("both")
ax.xaxis.set_ticks_position("both")
ax.legend(loc='center left', bbox_to_anchor=(0.1, 0.9), frameon=False, fontsize=18, ncol=4)
ax.set_xlim(start, end)
# ax.set_ylim(-0.01, 0.21)
useLargeSize(plt, ax)
plt.savefig("./nvt_data/{}".format(figname), dpi=300)

# %% [markdown]
# plot $E_{pot}$ distribution

# %%
plot_data = pot_e
figname = "c2_nvt_epot_distribution.png"
ylabel = r"Frequency"
xlabel = r"$E_{pot}\,$(eV)"

plt.style.use('default')
fig, ax = plt.subplots(figsize=(8,6))

for item in plot_data:
    sns.kdeplot(plot_data[item][:120], 
                shade = True, 
                linewidth = 3, 
                bw_adjust = 1, 
                label = item, 
                color = color[item],
            )

ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.tick_params(axis="y")
ax.yaxis.set_ticks_position("both")
ax.xaxis.set_ticks_position("both")
ax.legend(frameon=False, fontsize=18)
ax.set_xlim(-0.05, 0.2)
ax.set_ylim(0, 30)
useLargeSize(plt, ax)
plt.savefig("./nvt_data/{}".format(figname), dpi=300)

# %% [markdown]
# plot $E_{kin}$ v.s. Time

# %%
plot_data = kin_e

start, end = 0, min(1000, len(plot_data["DFT"]))
start, end = 0, 120
time = np.arange(end)
figname = "c2_nvt_ekin_{}.png".format(end)
xlabel = r"$T\,(fs)$"
ylabel = r"$E_{kin}\,(eV$)"

plt.style.use('default')
fig, ax = plt.subplots(figsize=(16,6))

for item in plot_data:
    ax.plot(time, 
            plot_data[item][start:end],
            c=color[item],
            label=item)

ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.tick_params(axis="y")
ax.yaxis.set_ticks_position("both")
ax.xaxis.set_ticks_position("both")
ax.legend(frameon=False, fontsize=18, ncol=4)
ax.set_xlim(start, end)
ax.set_ylim(-0.01, 0.179)
useLargeSize(plt, ax)
plt.savefig("./nvt_data/{}".format(figname), dpi=300)

# %% [markdown]
# plot $E_{kin}$ distribution

# %%
plot_data = kin_e
figname = "c2_nvt_ekin_distribution.png"
ylabel = r"Density"
xlabel = r"$E_{kin}\,$(eV)"

plt.style.use('default')
fig, ax = plt.subplots(figsize=(8,6))

for item in plot_data:
    sns.kdeplot(plot_data[item][:120], 
                shade = True, 
                linewidth = 3, 
                bw_adjust = 1, 
                label = item, 
                color = color[item],
            )

ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
ax.tick_params(axis="y")
ax.yaxis.set_ticks_position("both")
ax.xaxis.set_ticks_position("both")
ax.legend(frameon=False, fontsize=18)
ax.set_xlim(-0.05, 0.22)
ax.set_ylim(0, 18)
useLargeSize(plt, ax)
plt.savefig("./nvt_data/{}".format(figname), dpi=300)

# %% [markdown]
# ### Plot geometry v.s. time

# %%
data = {}

for item in file:
    data[item] = extract_geom(file[item])

observables = data[item].columns

# %% [markdown]
# plot observables v.s. time

# %%
for observable in observables:
    plot_data = {}
    for item in file:
        plot_data[item] = data[item][observable]

    xlabel = r"$T\,(fs)$"
    if "d" in observable:
        ylabel = observable + r"$\,({\AA})$"
    if "theta" in observable:
        ylabel = observable + r"$\,(degree)$"


    plt.style.use('default')
    fig, ax = plt.subplots(figsize=(16,6))

    min_len = float("inf")
    for item in plot_data:
        min_len = min(min_len, len(plot_data[item]))
    # start, end = 0, min(1000, min_len)
    start, end = 0, 120
    time = np.arange(end)

    for item in plot_data:
        ax.plot(time, 
                plot_data[item][start:end], 
                c=color[item], 
                label=item,
                )

    ax.set_xlabel(xlabel=xlabel)
    ax.set_ylabel(ylabel=ylabel)
    ax.tick_params(axis="y")
    ax.yaxis.set_ticks_position("both")
    ax.xaxis.set_ticks_position("both")
    ax.legend(loc=(0.28, 0.85), frameon=False, fontsize=18, ncol=4)
    ax.set_xlim(start, end)
    bottom, up = ax.get_ylim()
    ax.set_ylim(bottom, 1.02 * up)
    # ax.set_ylim(1.68, 2.21)
    useLargeSize(plt, ax)
    new_observable = ""
    for i in observable:
        if i not in {"\\","$", "{", "}", "-"}:
            new_observable += i 
    figname = "c2_nvt_{}.png".format(new_observable)
    # print(figname)
    plt.savefig("./nvt_data/{}".format(figname), dpi=300)

# %% [markdown]
# plot observables distribution

# %%
for observable in observables:
    plot_data = {}
    for item in file:
        plot_data[item] = data[item][observable]

    if "d" in observable:
        xlabel = observable + r"$\,({\AA})$"
    if "theta" in observable:
        xlabel = observable + r"$\,(degree)$"
    ylabel = "Density"

    plt.style.use('default')
    fig, ax = plt.subplots(figsize=(8,6))

    for item in plot_data:
        sns.kdeplot(plot_data[item][:120], 
                    shade = True, 
                    linewidth = 3, 
                    bw_adjust = 1, 
                    label = item, 
                    color = color[item],
                )

    ax.set_xlabel(xlabel=xlabel)
    ax.set_ylabel(ylabel=ylabel)
    ax.tick_params(axis="y")
    ax.yaxis.set_ticks_position("both")
    ax.xaxis.set_ticks_position("both")
    ax.legend(loc=(0.05, 0.65), frameon=False)
    ax.set_ylim(0, 19)
    if "Cl-C-H_{1}" in observable:
        left, right = ax.get_xlim()
        ax.set_xlim(left - 10, right)
    if "Cl-C-H" in observable:
        ax.legend(loc=(0.05, 0.6), frameon=False)
    if re.match(r".*H_{.*}-C-H_{.*}.*", observable):
        left, right = ax.get_xlim()
        ax.set_xlim(left, right + 5)

    useLargeSize(plt, ax)
    new_observable = ""
    for i in observable:
        if i not in {"\\","$", "{", "}", "-"}:
            new_observable += i 
    figname = "c2_nvt_{}_distribution.png".format(new_observable)
    # print(figname)
    plt.savefig("./nvt_data/{}".format(figname), dpi=300)
